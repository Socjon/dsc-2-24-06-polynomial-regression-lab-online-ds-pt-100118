# %% [markdown]
# # Polynomial Regression - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab you'll practice your knowledge on adding polynomial terms to your regression model!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
#
# - Understand how to account for non-linear relationships between predictors and target variable using polynomial terms

# %% [markdown]
# ## Create the best plot using polynomials!

# %% [markdown]
# Below, we created a plot with a clearly non-linear shape.
#
# - plot a polynomial function using `PolynomialFeatures` for polynomials up until the second, third and fourth degree.
# - print out the $R^2$ value for each of the three results. Draw conclusions with respect to which degree is best.

# %%
import numpy as np
import matplotlib.pyplot as plt

def pol(x):
    return x * np.cos(x)

x = np.linspace(0, 12, 100)
rng = np.random.RandomState(1234)
rng.shuffle(x)
x = np.sort(x[:25])
y = pol(x) + np.random.randn(25)*2

plt.scatter(x, y, color='green', s=50, marker='.')

plt.show();

# %% [markdown]
# ## Solution

# %%
x.shape, y.shape
# Out:
# ((25,), (25,))

# %%
## your code here
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd #import the library
import numpy as np

# %%
new_x = pd.DataFrame(x)

# %%
poly = PolynomialFeatures(4) #The degree of the polynomial. We will change this to check degrees 2, 3, and 4
x_trans = poly.fit_transform(new_x) #fitting AND transforming our x data (our actual values).

# %%
x_fit.shape, y.shape
# Out:
# ((25, 3), (25,))

# %%
from sklearn.linear_model import LinearRegression
reg_poly = LinearRegression()
reg_poly.fit(x_trans, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
x_linspace = pd.DataFrame(np.linspace(0,13,200)) #Creates a squence from 0->13 divided evenly 200 times
x_linspace_trans = poly.fit_transform(x_linspace) #Transformed the above squence by the T(x) where T is polynomial transformation

y_poly_pred = reg_poly.predict(x_linspace_trans) #predicting y_hat values from our transformed linspace

# %%
plt.scatter(x,y) #plotting the orginal points
plt.plot(x_linspace, y_poly_pred) #plotting the linspace and the predicted_y

# %% [markdown]
# I MADE IT WORK! So I now going to attemp to put it all in one block and see about making it work through a loop.

# %%
new_x = pd.DataFrame(x)
plt.scatter(x,y, label='True data') #plotting the orginal points
for i in range(7):
    poly = PolynomialFeatures(i) #The degree of the polynomial. We will change this to check degrees 2, 3, and 4
    x_trans = poly.fit_transform(new_x) #fitting AND transforming our x data (our actual values). 

    reg_poly = LinearRegression()
    reg_poly.fit(x_trans, y)

    x_linspace = pd.DataFrame(np.linspace(0,13,200)) #Creates a squence from 0->13 divided evenly 200 times
    x_linspace_trans = poly.fit_transform(x_linspace) #Transformed the above squence by the T(x) where T is polynomial transformation

    y_poly_pred = reg_poly.predict(x_linspace_trans)
    plt.plot(x_linspace, y_poly_pred, label=f'Polynomial with degree {i}') #plotting the linspace and the predicted_y

# %% [markdown]
# This is amazing.

# %% [markdown]
# ## Summary

# %% [markdown]
# Great! You now know how to include polynomials in your linear model!
